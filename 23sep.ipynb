# %%
s1= "Roshan Patode"
print(s1[: 6])
# Out:
# Roshan

# %%
s2 = "Roshan Patode"
print(s2[7:13])
# Out:
# Patode

# %%
s3 = "Roshan Patode"
print(s3[: 5])
# Out:
# Rosha

# %%
s4 = "Roshan Patode"
print(s4[7:12])
# Out:
# Patod

# %%
s5 = "Roshan Patode"
print(s5[0:13:2])
# Out:
# Rsa aoe

# %%
s5 = "Roshan Patode"
print(s5[7:11:2])
# Out:
# Pt

# %%
s6= "Roshan Patode"
print(s6[::-1])
# Out:
# edotaP nahsoR

# %%
s7= "Roshan Patode"
print(s7[:6:-1])
# Out:
# edotaP

# %%
s8= "Roshan Patode"
print(s8[2:7])
# Out:
# shan

# %%
s9= "Roshan Patode"
print(s9[:10:-1])
# Out:
# ed

# %%
s10= "Roshan Patode"
print(s10[::-2])
# Out:
# eoa asR

# %%
s11= "Roshan Patode"
print(s11[6:0:-1])
# Out:
#  nahso

# %%
s12= "Roshan Patode"
print(s12[7:0:-2])
# Out:
# Pnho

# %%
s13= "Roshan Patode"
print(s13[7:0:-1])
# Out:
# P nahso

# %%
s14 = "Roshan Patode"
print(s14[::-5])
# Out:
# ePs

# %%
s15 = "Roshan Patode"
print(s15[:6:-3])
# Out:
# et

# %%
a=9
print(a)
print(type(a))
print(id(a))
# Out:
# 9
# <class 'int'>
# 140715909899640

# %%
a=15
b=46
print(a+b)
print(id(a+b))
# Out:
# 61
# 140715909901304

# %%
a = int(input("Enter a number: "))
print(a)
print(type(a))
print(id(a))
# Out:
# 5
# <class 'int'>
# 140715909899512

# %%
price= 99.57
print(price)
print(type(price))
print(id(price))
# Out:
# 99.57
# <class 'float'>
# 1535820663568

# %%
name = "Roshan"
print(name)
print(type(name))
print(id(name))
# Out:
# Roshan
# <class 'str'>
# 1535798903264

# %%
age = 20
print(age>=18)
print(type(age))
print(id(age>=18))
# Out:
# True
# <class 'int'>
# 140715908999936

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits)
print(type(fruits))
print(id(fruits))
# Out:
# ['apple', 'banana', 'cherry']
# <class 'list'>
# 1535820783296

# %%
a = (101, 102, 103, 104, 105)
print(a)
print(type(a))
# Out:
# (101, 102, 103, 104, 105)
# <class 'tuple'>
